# %%
"""
Imports
"""
import sys
print(f"Python:\t{sys.version}")
import numpy as np
print(f"Numpy:\t\t{np.__version__}")
import tensorflow as tf
print(f"Tensorflow:\t{tf.__version__}")
import keras
print(f"Keras:\t\t{keras.__version__}")

import os
import matplotlib.pyplot as plt
from keras import Sequential
from keras import layers
from keras.applications import NASNetMobile # https://keras.io/api/applications/nasnet/#nasnetmobile-function
# Out:
# Python:	3.8.20 (default, Oct  3 2024, 15:19:54) [MSC v.1929 64 bit (AMD64)]
# Numpy:		1.23.3
# Tensorflow:	2.10.0
# Keras:		2.10.0

# %%
"""
Options
"""
model_name = "NasNet_70ftfl_60e_32b"

image_width = 128
image_height = 128
channels_dim = 3
classes_dim = 6
batch_size = 32

validation_split = 0.2
fine_tuning_frozen_layers = 0.7
base_learning_rate = 0.001
epochs_pretraining = 10
epochs_total = 60

shape = (image_height, image_width, channels_dim)

# %%
"""
Pathing
"""
SPECTROGRAMS_DIR = "../data/data_spectrograms/combined"
TF_MODELS_DIR = "../data/tf_models"
TFLITE_MODELS_DIR = "../data/tflite_models"

# %%
"""
Load data
"""
train = tf.keras.utils.image_dataset_from_directory(
    SPECTROGRAMS_DIR,
    validation_split=0.2,
    subset='training',
    image_size=(image_height, image_width),
    batch_size=batch_size,
    seed=123
)

valid = tf.keras.utils.image_dataset_from_directory(
    SPECTROGRAMS_DIR,
    validation_split=0.2,
    subset='validation',
    image_size=(image_height, image_width),
    batch_size=batch_size,
    seed=123
)

def one_hot_encode(image, label):
    label = tf.one_hot(label, depth=classes_dim)
    return image, label

train = train.map(one_hot_encode)
valid = valid.map(one_hot_encode)
# Out:
# Found 29768 files belonging to 6 classes.
# Using 23815 files for training.
# Found 29768 files belonging to 6 classes.
# Using 5953 files for validation.

# %%
"""
Clear session
"""
tf.keras.backend.clear_session()

"""
Preprocessing
"""
model_input = keras.Input(shape=(None, None, 3))
x = model_input
x = layers.Resizing(image_height, image_width)(x)
x = layers.Rescaling(1.0 / 255)(x)

"""
Build MobileNet model
"""

mobilenet = MobileNetV2(
    input_shape=shape,
    alpha=1.0,
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    pooling=None,
    classes=classes_dim,
    classifier_activation="softmax"
)

mobilenet.trainable = False
x = mobilenet(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dropout(0.25)(x)
mobilenet_output = layers.Dense(classes_dim, activation="softmax")(x)

mobilenet_model = keras.Model(model_input, mobilenet_output)
mobilenet_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
mobilenet_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  resizing (Resizing)         (None, 128, 128, 3)       0
#
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  mobilenetv2_1.00_128 (Funct  (None, 4, 4, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 2,422,726
# Trainable params: 164,742
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
"""
Train model
"""

history_pretraining = mobilenet_model.fit(train, validation_data=valid, epochs=epochs_pretraining)

plt.plot(history_pretraining.history['accuracy'], label='accuracy')
plt.plot(history_pretraining.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 745/745 [==============================] - 42s 45ms/step - loss: 1.4705 - accuracy: 0.3987 - val_loss: 1.3608 - val_accuracy: 0.4583
# Epoch 2/10
# 745/745 [==============================] - 29s 39ms/step - loss: 1.3765 - accuracy: 0.4452 - val_loss: 1.3259 - val_accuracy: 0.4742
# Epoch 3/10
# 745/745 [==============================] - 28s 38ms/step - loss: 1.3460 - accuracy: 0.4598 - val_loss: 1.3014 - val_accuracy: 0.4848
# Epoch 4/10
# 745/745 [==============================] - 28s 38ms/step - loss: 1.3173 - accuracy: 0.4716 - val_loss: 1.2921 - val_accuracy: 0.4930
# Epoch 5/10
# 745/745 [==============================] - 29s 38ms/step - loss: 1.2922 - accuracy: 0.4833 - val_loss: 1.2792 - val_accuracy: 0.4897
# Epoch 6/10
# 745/745 [==============================] - 30s 40ms/step - loss: 1.2731 - accuracy: 0.4922 - val_loss: 1.2539 - val_accuracy: 0.5056
# Epoch 7/10
# 745/745 [==============================] - 29s 39ms/step - loss: 1.2564 - accuracy: 0.4999 - val_loss: 1.2574 - val_accuracy: 0.5016
# Epoch 8/10
# 745/745 [==============================] - 29s 39ms/step - loss: 1.2362 - accuracy: 0.5069 - val_loss: 1.2449 - val_accuracy: 0.5110
# Epoch 9/10
# 745/745 [==============================] - 32s 42ms/step - loss: 1.2286 - accuracy: 0.5109 - val_loss: 1.2685 - val_accuracy: 0.4982
# Epoch 10/10
# 745/745 [==============================] - 33s 44ms/step - loss: 1.2107 - accuracy: 0.5200 - val_loss: 1.2157 - val_accuracy: 0.5171

# %%
"""
Fine tuning
"""
mobilenet.trainable = True
frozen_layers_amount = int(fine_tuning_frozen_layers * len(mobilenet.layers))
for layer in mobilenet.layers[:frozen_layers_amount]:
  layer.trainable = False
    
mobilenet_model.compile(
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=(base_learning_rate / 10)),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
mobilenet_model.summary()
history_fine_tuning = mobilenet_model.fit(train, validation_data=valid, epochs=epochs_total, initial_epoch=history_pretraining.epoch[-1])

plt.plot(history_fine_tuning.history["accuracy"], label="accuracy")
plt.plot(history_fine_tuning.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  resizing (Resizing)         (None, 128, 128, 3)       0
#
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  mobilenetv2_1.00_128 (Funct  (None, 4, 4, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 2,422,726
# Trainable params: 1,964,358
# Non-trainable params: 458,368
# _________________________________________________________________
# Epoch 10/60
# 745/745 [==============================] - 69s 81ms/step - loss: 1.6606 - accuracy: 0.3250 - val_loss: 1.4428 - val_accuracy: 0.4018
# Epoch 11/60
# 745/745 [==============================] - 61s 82ms/step - loss: 1.3986 - accuracy: 0.4413 - val_loss: 1.3835 - val_accuracy: 0.4389
# Epoch 12/60
# 745/745 [==============================] - 61s 81ms/step - loss: 1.3025 - accuracy: 0.4917 - val_loss: 1.2050 - val_accuracy: 0.5404
# Epoch 13/60
# 745/745 [==============================] - 59s 79ms/step - loss: 1.2365 - accuracy: 0.5238 - val_loss: 1.2194 - val_accuracy: 0.5389
# Epoch 14/60
# 745/745 [==============================] - 58s 78ms/step - loss: 1.1765 - accuracy: 0.5505 - val_loss: 1.5415 - val_accuracy: 0.4628
# Epoch 15/60
# 745/745 [==============================] - 61s 82ms/step - loss: 1.1267 - accuracy: 0.5722 - val_loss: 1.2783 - val_accuracy: 0.5187
# Epoch 16/60
# 745/745 [==============================] - 55s 73ms/step - loss: 1.0822 - accuracy: 0.5936 - val_loss: 1.1891 - val_accuracy: 0.5639
# 745/745 [==============================] - 56s 75ms/step - loss: 0.2855 - accuracy: 0.9170 - val_loss: 1.0518 - val_accuracy: 0.7460
# Epoch 58/60
# 745/745 [==============================] - 54s 72ms/step - loss: 0.2751 - accuracy: 0.9252 - val_loss: 1.9506 - val_accuracy: 0.7359
# Epoch 59/60
# 745/745 [==============================] - 55s 74ms/step - loss: 0.2813 - accuracy: 0.9220 - val_loss: 1.3076 - val_accuracy: 0.7448
# Epoch 60/60
# 745/745 [==============================] - 54s 72ms/step - loss: 0.2577 - accuracy: 0.9271 - val_loss: 2.8778 - val_accuracy: 0.6995

# %%
"""
Save model
"""
mobilenet_model.save(f"{TF_MODELS_DIR}/{model_name}")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../data/tf_models/EmoNet_ftfl_70\assets
# INFO:tensorflow:Assets written to: ../data/tf_models/EmoNet_ftfl_70\assets

# %%
"""
Train custom model
"""

model_input = keras.Input(shape=(None, None, 3))
x = model_input
x = layers.Resizing(image_height, image_width)(x)
x = layers.Rescaling(1.0 / 255)(x)

x = layers.Conv2D(16, (3, 3), activation="relu", padding="same", kernel_initializer="he_normal")(x)
x = layers.Conv2D(16, (3, 3), activation="relu", padding="same", kernel_initializer="he_normal")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(32, (3, 3), activation="relu", padding="same", kernel_initializer="he_normal")(x)
x = layers.Conv2D(32, (3, 3), activation="relu", padding="same", kernel_initializer="he_normal")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(64, (3, 3), activation="relu", padding="same", kernel_initializer="he_normal")(x)
x = layers.Conv2D(74, (3, 3), activation="relu", padding="same", kernel_initializer="he_normal")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Conv2D(128, (3, 3), activation="relu", padding="same", kernel_initializer="he_normal")(x)
x = layers.Conv2D(128, (3, 3), activation="relu", padding="same", kernel_initializer="he_normal")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Flatten()(x)
x = layers.Dense(64, activation="relu", kernel_initializer="he_normal")(x)
x = layers.Dropout(0.25)(x)
x = layers.Dense(64, activation="relu", kernel_initializer="he_normal")(x)
x = layers.Dropout(0.25)(x)

model_output = layers.Dense(classes_dim, activation="softmax")(x)
custom_model = keras.Model(inputs=model_input, outputs=model_output)
custom_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
custom_model.summary()
history_custom = custom_model.fit(train, validation_data=valid, epochs=epochs_total)

plt.plot(history_custom.history["accuracy"], label="accuracy")
plt.plot(history_custom.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

mobilenet_model.save(f"{TF_MODELS_DIR}/{model_name}_custom")
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, None, None, 3)]   0
#
#  resizing_9 (Resizing)       (None, 128, 128, 3)       0
#
#  rescaling_9 (Rescaling)     (None, 128, 128, 3)       0
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 16)      448
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 16)      2320
#
#  max_pooling2d_24 (MaxPoolin  (None, 64, 64, 16)       0
#  g2D)
#
#  conv2d_51 (Conv2D)          (None, 64, 64, 32)        4640
#
#  conv2d_52 (Conv2D)          (None, 64, 64, 32)        9248
#
#  max_pooling2d_25 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_53 (Conv2D)          (None, 32, 32, 64)        18496
#
#  conv2d_54 (Conv2D)          (None, 32, 32, 74)        42698
#
#  max_pooling2d_26 (MaxPoolin  (None, 16, 16, 74)       0
#  g2D)
#
#  conv2d_55 (Conv2D)          (None, 16, 16, 128)       85376
#
#  conv2d_56 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d_27 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 8192)              0
#
#  dense_18 (Dense)            (None, 64)                524352
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 64)                4160
#
#  dropout_14 (Dropout)        (None, 64)                0
#
#  dense_20 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 839,712
# Trainable params: 839,712
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 745/745 [==============================] - 44s 54ms/step - loss: 1.6241 - accuracy: 0.3098 - val_loss: 1.4575 - val_accuracy: 0.3958
# Epoch 2/60
# 745/745 [==============================] - 40s 54ms/step - loss: 1.4547 - accuracy: 0.4045 - val_loss: 1.4892 - val_accuracy: 0.3901
# Epoch 3/60
# 745/745 [==============================] - 40s 53ms/step - loss: 1.3681 - accuracy: 0.4516 - val_loss: 1.2537 - val_accuracy: 0.5018
# Epoch 4/60
# 745/745 [==============================] - 40s 53ms/step - loss: 1.2771 - accuracy: 0.4934 - val_loss: 1.1714 - val_accuracy: 0.5475
# Epoch 5/60
# 745/745 [==============================] - 43s 57ms/step - loss: 1.1742 - accuracy: 0.5376 - val_loss: 1.0579 - val_accuracy: 0.5928
# Epoch 6/60
# 745/745 [==============================] - 45s 60ms/step - loss: 1.0657 - accuracy: 0.5890 - val_loss: 0.9726 - val_accuracy: 0.6224
# Epoch 7/60
# 745/745 [==============================] - 44s 58ms/step - loss: 0.9604 - accuracy: 0.6317 - val_loss: 0.9131 - val_accuracy: 0.6464
# Epoch 8/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.8578 - accuracy: 0.6724 - val_loss: 0.8460 - val_accuracy: 0.6818
# Epoch 9/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.7660 - accuracy: 0.7090 - val_loss: 0.7753 - val_accuracy: 0.7084
# Epoch 10/60
# 745/745 [==============================] - 44s 58ms/step - loss: 0.6916 - accuracy: 0.7343 - val_loss: 0.7302 - val_accuracy: 0.7264
# Epoch 11/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.6254 - accuracy: 0.7641 - val_loss: 0.6453 - val_accuracy: 0.7571
# Epoch 12/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.5646 - accuracy: 0.7859 - val_loss: 0.6002 - val_accuracy: 0.7806
# Epoch 13/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.5098 - accuracy: 0.8086 - val_loss: 0.5988 - val_accuracy: 0.7830
# Epoch 14/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.4705 - accuracy: 0.8210 - val_loss: 0.5233 - val_accuracy: 0.8130
# Epoch 15/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.4362 - accuracy: 0.8356 - val_loss: 0.5485 - val_accuracy: 0.8147
# Epoch 16/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.4159 - accuracy: 0.8436 - val_loss: 0.5021 - val_accuracy: 0.8263
60
# 745/745 [==============================] - 43s 57ms/step - loss: 0.1641 - accuracy: 0.9442 - val_loss: 0.2925 - val_accuracy: 0.9143
# Epoch 44/60
# 745/745 [==============================] - 43s 57ms/step - loss: 0.1492 - accuracy: 0.9486 - val_loss: 0.3229 - val_accuracy: 0.9056
# Epoch 45/60
# 745/745 [==============================] - 43s 58ms/step - loss: 0.1391 - accuracy: 0.9526 - val_loss: 0.3022 - val_accuracy: 0.9153
# Epoch 46/60
# 745/745 [==============================] - 43s 57ms/step - loss: 0.1410 - accuracy: 0.9534 - val_loss: 0.3333 - val_accuracy: 0.9063
# Epoch 47/60
# 745/745 [==============================] - 43s 58ms/step - loss: 0.1381 - accuracy: 0.9514 - val_loss: 0.3199 - val_accuracy: 0.9123
# Epoch 48/60
# 745/745 [==============================] - 43s 58ms/step - loss: 0.1447 - accuracy: 0.9510 - val_loss: 0.2888 - val_accuracy: 0.9160
# Epoch 49/60
# 745/745 [==============================] - 43s 57ms/step - loss: 0.1262 - accuracy: 0.9559 - val_loss: 0.3188 - val_accuracy: 0.9209
# Epoch 50/60
# 745/745 [==============================] - 43s 58ms/step - loss: 0.1285 - accuracy: 0.9568 - val_loss: 0.3185 - val_accuracy: 0.9157
# Epoch 51/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.1224 - accuracy: 0.9588 - val_loss: 0.3601 - val_accuracy: 0.9128
# Epoch 52/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.1369 - accuracy: 0.9532 - val_loss: 0.3482 - val_accuracy: 0.9051
# Epoch 53/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.1244 - accuracy: 0.9588 - val_loss: 0.3212 - val_accuracy: 0.9105
# Epoch 54/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.1217 - accuracy: 0.9599 - val_loss: 0.3005 - val_accuracy: 0.9167
# Epoch 55/60
# 745/745 [==============================] - 44s 59ms/step - loss: 0.1143 - accuracy: 0.9617 - val_loss: 0.3425 - val_accuracy: 0.9158
# Epoch 56/60
# 745/745 [==============================] - 44s 60ms/step - loss: 0.1118 - accuracy: 0.9629 - val_loss: 0.3557 - val_accuracy: 0.9049
# Epoch 57/60
# 745/745 [==============================] - 46s 62ms/step - loss: 0.1315 - accuracy: 0.9555 - val_loss: 0.2657 - val_accuracy: 0.9284
# Epoch 58/60
# 745/745 [==============================] - 46s 62ms/step - loss: 0.1132 - accuracy: 0.9621 - val_loss: 0.3309 - val_accuracy: 0.9091
# Epoch 59/60
# 745/745 [==============================] - 46s 62ms/step - loss: 0.1192 - accuracy: 0.9623 - val_loss: 0.2595 - val_accuracy: 0.9300
# Epoch 60/60
# 745/745 [==============================] - 49s 66ms/step - loss: 0.1131 - accuracy: 0.9622 - val_loss: 0.2899 - val_accuracy: 0.9259
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 52). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../data/tf_models/EmoNet_ftfl_70_custom\assets
# INFO:tensorflow:Assets written to: ../data/tf_models/EmoNet_ftfl_70_custom\assets

# %%
"""
Convert SavedModel (TensorFlow) to .tflite
"""
converter = tf.lite.TFLiteConverter.from_saved_model(f"{TF_MODELS_DIR}/{model_name}")
tflite_model = converter.convert()

with open(f"{TFLITE_MODELS_DIR}/{model_name}.tflite", "wb") as f:
  f.write(tflite_model)
